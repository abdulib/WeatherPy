# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?"
#query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
#weather_response = requests.get(query_url).json()
#weather_response

# %%
#cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#city_name = weather_response['name']
        #temperature = weather_response['main']['temp']
        #humidity = weather_response['main']['humidity']
        #cloudiness = weather_response['clouds']['all']
        #wind_speed = weather_response['wind']['speed']
        #date = weather_response['dt']
        #country = weather_response['sys']['country']
        #max_temp = weather_response['main']['temp_max']
        #lat = weather_response['coord']['lat']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

city_name_list = []
temperature_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []
date_list = []
max_temp_list = []
lat_list = []
lng_list = []

print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities: 
    try:
        query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
        weather_response = requests.get(query_url).json()
        print(f"Processing Record {cities.index(city) + 1} of Set 1 | {city}")
        lng = weather_response['coord']['lon']
        city_name_list.append(weather_response['name'])
        temperature_list.append(weather_response['main']['temp'])
        cloudiness_list.append(weather_response['clouds']['all'])
        wind_speed_list.append(weather_response['wind']['speed'])
        date_list.append(weather_response['dt'])
        country_list.append(weather_response['sys']['country'])
        max_temp_list.append(weather_response['main']['temp_max'])
        lat_list.append(weather_response['coord']['lat'])
        lng_list.append(weather_response['coord']['lon'])
        humidity_list.append(weather_response['main']['humidity'])
    except KeyError:
        print("City not found. Skipping...")
        
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | marovoay
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | yerbogachen
# Processing Record 7 of Set 1 | bure
# Processing Record 8 of Set 1 | kavaratti
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | asau
# City not found. Skipping...
# Processing Record 11 of Set 1 | laguna
# Processing Record 12 of Set 1 | chokurdakh
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | sainte-marie
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | mikkeli
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | makakilo city
# Processing Record 22 of Set 1 | iraucuba
# Processing Record 23 of Set 1 | tuatapere
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | sao jose da coroa grande
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | abu samrah
# Processing Record 30 of Set 1 | bindki
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | olafsvik
# City not found. Skipping...
# Processing Record 33 of Set 1 | viransehir
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | lenoir city
# Processing Record 38 of Set 1 | ierapetra
# Processing Record 39 of Set 1 | isangel
# Processing Record 40 of Set 1 | maniitsoq
# Processing Record 41 of Set 1 | pascagoula
# Processing Record 42 of Set 1 | milove
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | hami
# Processing Record 45 of Set 1 | camana
# City not found. Skipping...
# Processing Record 46 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 1 | trairi
# Processing Record 48 of Set 1 | herat
# Processing Record 49 of Set 1 | muroto
# Processing Record 50 of Set 1 | cape town
# Processing Record 51 of Set 1 | naze
# Processing Record 52 of Set 1 | turtas
# Processing Record 53 of Set 1 | hilo
# Processing Record 54 of Set 1 | atuona
# Processing Record 55 of Set 1 | pointe michel
# Processing Record 56 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 57 of Set 1 | lucea
# Processing Record 58 of Set 1 | charters towers
# Processing Record 59 of Set 1 | georgetown
# Processing Record 60 of Set 1 | khatanga
# Processing Record 61 of Set 1 | butaritari
# Processing Record 62 of Set 1 | maloshuyka
# City not found. Skipping...
# Processing Record 63 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record
# Processing Record 212 of Set 1 | cayenne
# Processing Record 213 of Set 1 | mogadishu
# Processing Record 214 of Set 1 | gaur
# Processing Record 215 of Set 1 | hithadhoo
# Processing Record 216 of Set 1 | ulaangom
# Processing Record 217 of Set 1 | landazuri
# Processing Record 218 of Set 1 | nanortalik
# Processing Record 219 of Set 1 | inhambane
# Processing Record 220 of Set 1 | nizwa
# Processing Record 221 of Set 1 | zhongxing
# Processing Record 222 of Set 1 | nome
# Processing Record 223 of Set 1 | coahuayana
# Processing Record 224 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 225 of Set 1 | marzuq
# Processing Record 226 of Set 1 | topeka
# Processing Record 227 of Set 1 | bitung
# Processing Record 228 of Set 1 | russell
# Processing Record 229 of Set 1 | puerto ayora
# Processing Record 230 of Set 1 | tazovskiy
# Processing Record 231 of Set 1 | oktyabrskiy
# Processing Record 232 of Set 1 | corralillo
# Processing Record 233 of Set 1 | cortes
# Processing Record 234 of Set 1 | kapoeta
# City not found. Skipping...
# Processing Record 235 of Set 1 | singaraja
# Processing Record 236 of Set 1 | gerash
# Processing Record 237 of Set 1 | lysyanka
# Processing Record 238 of Set 1 | margate
# Processing Record 239 of Set 1 | tevaitoa
# Processing Record 240 of Set 1 | biltine
# Processing Record 241 of Set 1 | jumla
# Processing Record 242 of Set 1 | sumbawanga
# Processing Record 243 of Set 1 | clyde river
# Processing Record 244 of Set 1 | tura
# Processing Record 245 of Set 1 | bambanglipuro
# Processing Record 246 of Set 1 | guerrero negro
# Processing Record 247 of Set 1 | ovre ardal
# Processing Record 248 of Set 1 | shelburne
# Processing Record 249 of Set 1 | puerto colombia
# Processing Record 250 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 251 of Set 1 | mazagao
# Processing Record 252 of Set 1 | airai
# Processing Record 253 of Set 1 | severo-kurilsk
# Processing Record 254 of Set 1 | kinablangan
# Processing Record 255 of Set 1 | braine-le-comte
# Processing Record 256 of Set 1 | codajas
# Processing Record 257 of Set 1 | plaster rock
# Processing Record 258 of Set 1 | hasaki
# Processing Record 259 of Set 1 | richmond
# Processing Record 260 of Set 1 | wyndham
# Processing Record 261 of Set 1 | shirokiy
# Processing Record 262 of Set 1 | yuncheng
# Processing Record 263 of Set 1 | trincomalee
# Processing Record 264 of Set 1 | amontada
# Processing Record 265 of Set 1 | saint-philippe
# Processing Record 266 of Set 1 | lamu
# Processing Record 267 of Set 1 | birin
# Processing Record 268 of Set 1 | camacha
# Processing Record 269 of Set 1 | mingshui
# Processing Record 270 of Set 1 | talakan
# Processing Record 271 of Set 1 | pore
# Processing Record 272 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 273 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 274 of Set 1 | marsa matruh
# Processing Record 275 of Set 1 | brae
# Processing Record 276 of Set 1 | sarakhs
# Processing Record 277 of Set 1 | bazarnyye mataki
# Processing Record 278 of Set 1 | dunedin
# Processing Record 279 of Set 1 | talnakh
# Processing Record 280 of Set 1 | wewak
# Processing Record 281 of Set 1 | menongue
# Processing Record 282 of Set 1 | san cristobal
# Processing Record 283 of Set 1 | anadyr
# Processing Record 284 of Set 1 | los llanos de aridane
# Processing Record 285 of Set 1 | dragor
# Processing Record 286 of Set 1 | cabo san lucas
# Processing Record 287 of Set 1 | ormara
# Processing Record 288 of Set 1 | te anau
# Processing Record 289 of Set 1 | itarema
# Processing Record 290 of Set 1 | romodanovo
# Processing Record 291 of Set 1 | torbay
# Processing Record 292 of Set 1 | miyako
# Processing Record 293 of Set 1 | rungata
# City not found. Skipping...
# Processing Record
# Processing Record 516 of Set 1 | kremasti
# Processing Record 517 of Set 1 | zheleznodorozhnyy
# Processing Record 518 of Set 1 | port macquarie
# Processing Record 519 of Set 1 | preeceville
# Processing Record 520 of Set 1 | baiquan
# Processing Record 521 of Set 1 | ibb
# Processing Record 522 of Set 1 | paamiut
# Processing Record 523 of Set 1 | unai
# Processing Record 524 of Set 1 | beloha
# Processing Record 525 of Set 1 | marathon
# Processing Record 526 of Set 1 | vardo
# Processing Record 527 of Set 1 | san patricio
# Processing Record 528 of Set 1 | hegang
# Processing Record 529 of Set 1 | atbasar
# Processing Record 530 of Set 1 | inongo
# Processing Record 531 of Set 1 | zhangjiakou
# Processing Record 532 of Set 1 | isernia
# Processing Record 533 of Set 1 | tecoanapa
# Processing Record 534 of Set 1 | puerto del rosario
# Processing Record 535 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 536 of Set 1 | pecos
# Processing Record 537 of Set 1 | lulea
# Processing Record 538 of Set 1 | iwanai
# Processing Record 539 of Set 1 | nizhniy tsasuchey
# Processing Record 540 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 541 of Set 1 | haines junction
# Processing Record 542 of Set 1 | taoudenni
# Processing Record 543 of Set 1 | astaneh-ye ashrafiyeh
# Processing Record 544 of Set 1 | wawa
# Processing Record 545 of Set 1 | plonsk
# Processing Record 546 of Set 1 | gbarnga
# Processing Record 547 of Set 1 | aklavik
# Processing Record 548 of Set 1 | bilibino
# Processing Record 549 of Set 1 | ballina
# Processing Record 550 of Set 1 | sangar
# Processing Record 551 of Set 1 | pilar
# Processing Record 552 of Set 1 | praia da vitoria
# Processing Record 553 of Set 1 | eenhana
# Processing Record 554 of Set 1 | port moresby
# Processing Record 555 of Set 1 | zalantun
# Processing Record 556 of Set 1 | tromso
# Processing Record 557 of Set 1 | ixtapa
# Processing Record 558 of Set 1 | rio grande
# Processing Record 559 of Set 1 | gorontalo
# Processing Record 560 of Set 1 | klaksvik
# Processing Record 561 of Set 1 | huilong
# Processing Record 562 of Set 1 | washougal
# Processing Record 563 of Set 1 | sao filipe
# Processing Record 564 of Set 1 | port hawkesbury
# Processing Record 565 of Set 1 | mount isa
# Processing Record 566 of Set 1 | sorland
# Processing Record 567 of Set 1 | dabola
# Processing Record 568 of Set 1 | meadow lake
# Processing Record 569 of Set 1 | santarem
# City not found. Skipping...
# Processing Record 570 of Set 1 | lhokseumawe
# Processing Record 571 of Set 1 | high rock
# Processing Record 572 of Set 1 | didsbury
# Processing Record 573 of Set 1 | sioux lookout
# Processing Record 574 of Set 1 | maningrida
# Processing Record 575 of Set 1 | tibacuy
# Processing Record 576 of Set 1 | marsaxlokk
# Processing Record 577 of Set 1 | kysyl-syr
# Processing Record 578 of Set 1 | makubetsu
# Processing Record 579 of Set 1 | puerto escondido
# Processing Record 580 of Set 1 | kachug
# Processing Record 581 of Set 1 | oparino
# Processing Record 582 of Set 1 | mhlume
# Processing Record 583 of Set 1 | monrovia
# Processing Record 584 of Set 1 | aspindza
# Processing Record 585 of Set 1 | carauari
# Processing Record 586 of Set 1 | yokadouma
# Processing Record 587 of Set 1 | hazorasp
# Processing Record 588 of Set 1 | kabul
# Processing Record 589 of Set 1 | dossor
# Processing Record 590 of Set 1 | wladyslawowo
# Processing Record 591 of Set 1 | bacolod
# Processing Record 592 of Set 1 | hutang
# Processing Record 593 of Set 1 | pyay
# Processing Record 594 of Set 1 | churapcha
# Processing Record 595 of Set 1 | shubarshi
# Processing Record 596 of Set 1 | acajutla
# Processing Record 597 of Set 1 | fort-shevchenko
# Processing Record 598 of Set 1 | santo antonio do sudoeste
# Processing Record 599 of Set 1 | pangoa
# Processing Record 600 of Set 1 | cacak
# Processing Record 601 of Set 1 | ostrovnoy
# Processing Record 602 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 603 of Set 1 | svetlogorsk
# Processing Record 604 of Set 1 | kaeo
# Processing Record 605 of Set 1 | riyadh
# Processing Record 606 of Set 1 | heihe
# Processing Record 607 of Set 1 | taltal
# Processing Record 608 of Set 1 | almaznyy
# Processing Record 609 of Set 1 | sinnar
# Processing Record 610 of Set 1 | monte patria
# Processing Record 611 of Set 1 | winnemucca
# Processing Record 612 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 613 of Set 1 | calderitas
# Processing Record 614 of Set 1 | kenai
# Processing Record 615 of Set 1 | kourou
# Processing Record 616 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 617 of Set 1 | santa cruz de tenerife
# Processing Record 618 of Set 1 | jejuri
# Processing Record 619 of Set 1 | makung
# City not found. Skipping...
# Processing Record 620 of Set 1 | alice springs
# Processing Record 621 of Set 1 | zhigansk
# Processing Record 622 of Set 1 | sumbe
# Processing Record 623 of Set 1 | catamarca
# City not found. Skipping...
# Processing Record 624 of Set 1 | nola
# Processing Record 625 of Set 1 | waingapu
# Processing Record 626 of Set 1 | shimoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = {
    "City": city_name_list,
    "Cloudiness": cloudiness_list,
    "Country": country_list,
    "Date": date_list,
    "Humidity": humidity_list,
    "Lat": lat_list,
    "Lng": lng_list,
    "Max Temp": max_temp_list,
    "Wind Speed": wind_speed_list
}
weather_df = pd.DataFrame(weather_df)

weather_df.count()
# Out:
# City          560
# Cloudiness    560
# Country       560
# Date          560
# Humidity      560
# Lat           560
# Lng           560
# Max Temp      560
# Wind Speed    560
# dtype: int64

# %%
#clean data by dropping outliers
weather_df = weather_df[weather_df.Humidity < 100]

# %%
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Tasiilaq          75      GL  1553262600        79  65.61  -37.64
# 1  Busselton          12      AU  1553267116        47 -33.64  115.35
# 2   Marovoay          20      MG  1553263200        79 -16.11   46.64
# 3    Ushuaia          75      AR  1553263200        87 -54.81  -68.31
# 4      Bluff          48      AU  1553267197        69 -23.58  149.07
#
#    Max Temp  Wind Speed
# 0     19.40        5.82
# 1     57.99       20.09
# 2     86.00        9.17
# 3     46.40        3.31
# 4     75.07        7.67

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (/03/17/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Max Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(03/17/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs. Humidity Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(03/17/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs. Cloudiness Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(03/17/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs. Wind Speed.png")

# Show plot
plt.show()
